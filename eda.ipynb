# %%
# %load_ext autoreload
# %autoreload 2

# %%
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from collections import Counter
from functools import partial
from tqdm.cli import tqdm
from pathlib import Path
from sklearn.model_selection import train_test_split

from src.utils import fprint
from src.utils import percent_of
from src.utils import mape
from src.utils import create_submit_df

# %%
data_folder = Path("data")
submissions_folder = Path("submissions")

train_df = pd.read_csv(data_folder / "train.csv", index_col=0)
test_df = pd.read_csv(data_folder / "test_no_target.csv", index_col=0)
zipcodes_df = pd.read_csv(data_folder / "zipcodes.csv", index_col=0)

train_df = pd.merge(train_df.reset_index(), zipcodes_df.drop_duplicates("zipcode"), on="zipcode", how="left")
test_df = pd.merge(test_df.reset_index(), zipcodes_df.drop_duplicates("zipcode"), on="zipcode", how="left")

# %%
cat_features = ["type", "gearbox", "model", "fuel", "brand", "city"]

# %%
percent_of(train_df.insurance_price.isna())
# Out:
# 0.14662

# %%
train_df.registration_year.max()
# Out:
# 2016

# %%
train_df, val_df = train_test_split(train_df)

# %%
test_df
# Out:
#        index  engine_capacity           type  registration_year gearbox  \
# 0      60314              1.6      small car               2013  manual
# 1      12566              NaN          coupé               2004    auto
# 2      17760              NaN  station wagon               2006    auto
# 3       8876              NaN      limousine                 99  manual
# 4      80392              NaN      limousine               1975  manual
# ...      ...              ...            ...                ...     ...
# 49995  93878              1.4      limousine               1999  manual
# 49996  99783              NaN  station wagon               2002    auto
# 49997  57399              NaN      small car               2005  manual
# 49998  97106              NaN            bus               2001  manual
# 49999    478              NaN      limousine               1994  manual
#
#        power        model  mileage      fuel          brand  damage  zipcode  \
# 0        136        swift    40000  gasoline         suzuki     0.0    30449
# 1        333          6er   150000  gasoline            bmw     0.0    45307
# 2        170     e_klasse   150000    diesel  mercedes_benz     0.0    59494
# 3        101        astra   150000  gasoline           opel     NaN    25524
# 4         54       andere   150000    diesel  mercedes_benz     0.0    70794
# ...      ...          ...      ...       ...            ...     ...      ...
# 49995     86      corolla   150000  gasoline         toyota     0.0    44339
# 49996    184          3er   150000    diesel            bmw     0.0    47574
# 49997     52          fox   100000  gasoline     volkswagen     0.0    50389
# 49998    151  transporter   150000    diesel     volkswagen     0.0    12209
# 49999    116       vectra   150000  gasoline           opel     0.0    15517
#
#        insurance_price                        city   latitude  longitude
# 0                490.0                    Hannover  52.384470   9.726930
# 1                670.0                 Essen, Ruhr  51.462488   7.008645
# 2                460.0            Soest, Westfalen  51.566980   8.110620
# 3                  NaN       Heiligenstedtenerkamp  53.899874   9.468966
# 4               1110.0                 Filderstadt  48.666700   9.216670
# ...                ...                         ...        ...        ...
# 49995            110.0                    Dortmund  51.504225   7.483654
# 49996            240.0                        Goch  51.679880   6.156480
# 49997             60.0        Wesseling, Rheinland  50.833300   6.983330
# 49998            930.0  Berlin Steglitz-Zehlendorf  52.443640  13.229080
# 49999             70.0        Fürstenwalde / Spree  52.367690  14.071620
#
# [50000 rows x 16 columns]

# %%
val_df.shape, test_df.shape
# Out:
# ((9375, 17), (50000, 16))

# %%
    
unzip_val_df, unzip_test_df = unzip_dataframes(zip_dataframes(val_df, test_df))

# %%
unzip_val_df.shape, unzip_test_df.shape
# Out:
# ((9375, 17), (50000, 17))

# %%
val_df.head()
# Out:
#        index  engine_capacity       type  registration_year gearbox  power  \
# 9794   48812              2.0        bus               2005    auto    140
# 25077  25402              NaN  limousine               2003  manual    143
# 49606  21276              NaN        NaN               2000  manual    101
# 4715   17797              2.5  limousine               2002    auto    179
# 26701  65073              NaN  limousine               2001  manual    192
#
#           model  mileage                     fuel          brand  damage  \
# 9794     touran   150000                   diesel     volkswagen     1.0
# 25077  c_klasse   150000                 gasoline  mercedes_benz     0.0
# 49606    zafira   150000                      NaN           opel     0.0
# 4715         a8   150000                   diesel           audi     0.0
# 26701       3er   150000  liquefied petroleum gas            bmw     0.0
#
#        zipcode  insurance_price  price                 city   latitude  \
# 9794     89155            420.0   3458       Erbach (Donau)  48.333300
# 25077    65589            390.0   4823  Hadamar, Westerwald  50.450000
# 49606    47137             60.0    818             Duisburg  51.435110
# 4715     48268            120.0   2548    Greven, Westfalen  52.096678
# 26701    35713            430.0   3822           Eschenburg  50.808300
#
#        longitude  df_order
# 9794    9.883330         0
# 25077   8.050000         0
# 49606   6.763010         0
# 4715    7.616927         0
# 26701   8.358330         0

# %%
unzip_val_df.head()
# Out:
#        index  engine_capacity       type  registration_year gearbox  power  \
# 9794   48812              2.0        bus               2005    auto    140
# 25077  25402              NaN  limousine               2003  manual    143
# 49606  21276              NaN        NaN               2000  manual    101
# 4715   17797              2.5  limousine               2002    auto    179
# 26701  65073              NaN  limousine               2001  manual    192
#
#           model  mileage                     fuel          brand  damage  \
# 9794     touran   150000                   diesel     volkswagen     1.0
# 25077  c_klasse   150000                 gasoline  mercedes_benz     0.0
# 49606    zafira   150000                      NaN           opel     0.0
# 4715         a8   150000                   diesel           audi     0.0
# 26701       3er   150000  liquefied petroleum gas            bmw     0.0
#
#        zipcode  insurance_price   price                 city   latitude  \
# 9794     89155            420.0  3458.0       Erbach (Donau)  48.333300
# 25077    65589            390.0  4823.0  Hadamar, Westerwald  50.450000
# 49606    47137             60.0   818.0             Duisburg  51.435110
# 4715     48268            120.0  2548.0    Greven, Westfalen  52.096678
# 26701    35713            430.0  3822.0           Eschenburg  50.808300
#
#        longitude
# 9794    9.883330
# 25077   8.050000
# 49606   6.763010
# 4715    7.616927
# 26701   8.358330
